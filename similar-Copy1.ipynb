# %%
import pandas as pd
fp = pd.read_csv("first_person.csv")
sp = pd.read_csv("second_person.csv")

# %%
fp = fp.iloc[: , 1:]
sp = sp.iloc[: , 1:]

# %%
sp.head()
# Out:
#    LEFT_SHOULDER_X  LEFT_SHOULDER_Y  LEFT_SHOULDER_Z  RIGHT_SHOULDER_X  \
# 0         0.488927         0.380859        -0.278002          0.413728
# 1         0.484771         0.380538        -0.324178          0.407446
# 2         0.482889         0.380249        -0.331942          0.404539
# 3         0.475986         0.380287        -0.343926          0.396488
# 4         0.471579         0.380940        -0.340540          0.392553
#
#    RIGHT_SHOULDER_Y  RIGHT_SHOULDER_Z  LEFT_ELBOW_X  LEFT_ELBOW_Y  \
# 0          0.388430         -0.183080      0.493879      0.428199
# 1          0.389234         -0.186375      0.494510      0.424416
# 2          0.389658         -0.196510      0.489849      0.424415
# 3          0.389946         -0.201762      0.481489      0.424443
# 4          0.389980         -0.201062      0.474573      0.424555
#
#    LEFT_ELBOW_Z  RIGHT_ELBOW_X  ...  LEFT_HEEL_Z  RIGHT_HEEL_X  RIGHT_HEEL_Y  \
# 0     -0.276959       0.438901  ...    -0.100490      0.447157      0.569125
# 1     -0.320268       0.435581  ...    -0.143054      0.444018      0.569653
# 2     -0.316152       0.432685  ...    -0.138625      0.444118      0.570051
# 3     -0.328007       0.425387  ...    -0.167186      0.438175      0.570049
# 4     -0.321043       0.420773  ...    -0.161183      0.434459      0.570076
#
#    RIGHT_HEEL_Z  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  LEFT_FOOT_INDEX_Z  \
# 0     -0.034954           0.479736           0.574795          -0.233203
# 1     -0.018553           0.477959           0.574738          -0.283865
# 2     -0.002118           0.476216           0.574661          -0.281964
# 3      0.018319           0.467853           0.574707          -0.312747
# 4      0.001896           0.460609           0.574701          -0.300319
#
#    RIGHT_FOOT_INDEX_X  RIGHT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_Z
# 0            0.399668            0.573073           -0.153872
# 1            0.395477            0.573093           -0.137487
# 2            0.394239            0.573433           -0.124313
# 3            0.391305            0.573586           -0.102706
# 4            0.388889            0.573699           -0.117975
#
# [5 rows x 48 columns]

# %%
fp.head()
# Out:
#    LEFT_SHOULDER_X  LEFT_SHOULDER_Y  LEFT_SHOULDER_Z  RIGHT_SHOULDER_X  \
# 0         0.571178         0.425766        -0.104015          0.554026
# 1         0.570931         0.428420        -0.100361          0.553907
# 2         0.570780         0.429787        -0.099161          0.553824
# 3         0.570050         0.431232        -0.095383          0.553532
# 4         0.569362         0.433093        -0.088930          0.553266
#
#    RIGHT_SHOULDER_Y  RIGHT_SHOULDER_Z  LEFT_ELBOW_X  LEFT_ELBOW_Y  \
# 0          0.437039          0.116349      0.578167      0.525713
# 1          0.437867          0.130822      0.576451      0.527372
# 2          0.438616          0.132507      0.575554      0.528073
# 3          0.440568          0.131761      0.573461      0.529385
# 4          0.444013          0.138503      0.572898      0.531745
#
#    LEFT_ELBOW_Z  RIGHT_ELBOW_X  ...  LEFT_HEEL_Z  RIGHT_HEEL_X  RIGHT_HEEL_Y  \
# 0     -0.074459       0.563530  ...    -0.097869      0.571979      0.885664
# 1     -0.081071       0.562047  ...    -0.092239      0.575774      0.885927
# 2     -0.083174       0.561278  ...    -0.086334      0.577578      0.885927
# 3     -0.076830       0.560540  ...    -0.095456      0.578432      0.885814
# 4     -0.075248       0.559820  ...    -0.106483      0.572738      0.884053
#
#    RIGHT_HEEL_Z  LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  LEFT_FOOT_INDEX_Z  \
# 0      0.117984           0.567322           0.902119          -0.153659
# 1      0.083361           0.563761           0.902244          -0.142461
# 2      0.077579           0.563273           0.902269          -0.135321
# 3      0.076757           0.561092           0.902652          -0.137021
# 4      0.087329           0.561198           0.902682          -0.147197
#
#    RIGHT_FOOT_INDEX_X  RIGHT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_Z
# 0            0.535911            0.891445            0.082936
# 1            0.538319            0.891688            0.045806
# 2            0.540448            0.892015            0.039421
# 3            0.540058            0.892731            0.041240
# 4            0.533926            0.892936            0.041752
#
# [5 rows x 48 columns]

# %%
c_n = fp.columns.values.tolist()
# c_n

# %%
for x in range(fp.shape[1]):
    fp.iloc[:,x].plot(),sp.iloc[:,x].plot()

# %%
fp.LEFT_SHOULDER_Y.plot(),sp.LEFT_SHOULDER_Y.plot()
# Out:
# (<AxesSubplot: >, <AxesSubplot: >)

# %%
fp.LEFT_ELBOW_X.plot(),sp.LEFT_ELBOW_X.plot()
# Out:
# (<AxesSubplot: >, <AxesSubplot: >)

# %%
df.LEFT_SHOULDER_Y.plot(), js.LEFT_SHOULDER_Y.plot()
# Out:
# (<AxesSubplot: >, <AxesSubplot: >)
