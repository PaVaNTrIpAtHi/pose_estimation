# %% [markdown]
# # 0. Install and Import Dependencies

# %%
import cv2
import pandas as pd
import mediapipe as mp
import numpy as np
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
# !pip install pandas

# %%
# VIDEO FEED
cap = cv2.VideoCapture("hs.mp4")
while cap.isOpened():
    ret, frame = cap.read()
    if ret == True:
#         print(ret)
        cv2.imshow('Mediapipe Feed', frame)
    
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    else:
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
# !pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-12.1.0-py3-none-any.whl (56 kB)
#      -------------------------------------- 56.5/56.5 kB 984.7 kB/s eta 0:00:00
# Installing collected packages: pytube
# Successfully installed pytube-12.1.0

# %% [markdown]
# # download data from youtube

# %%
# importing the module
from pytube import YouTube

# where to save
SAVE_PATH = "C:/Users/Hi/research/dhoni/"
yt = YouTube('https://www.youtube.com/shorts/gMniZDw-6Yg')
yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution')[-1].download()
# Out:
# 'C:\\Users\\Hi\\research\\dhoni\\Helicopter shot practice youtubeshorts.mp4'

# %%
print(results)
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>

# %%
col_names = []
for lndmrk in mp_pose.PoseLandmark:
    col_names.append(str(lndmrk)[13:]+"_X")
    col_names.append(str(lndmrk)[13:]+"_Y")
    col_names.append(str(lndmrk)[13:]+"_Z")

# %%
df = pd.DataFrame(columns=col_names)
df
# Out:
# Empty DataFrame
# Columns: [NOSE_X, NOSE_Y, NOSE_Z, LEFT_EYE_INNER_X, LEFT_EYE_INNER_Y, LEFT_EYE_INNER_Z, LEFT_EYE_X, LEFT_EYE_Y, LEFT_EYE_Z, LEFT_EYE_OUTER_X, LEFT_EYE_OUTER_Y, LEFT_EYE_OUTER_Z, RIGHT_EYE_INNER_X, RIGHT_EYE_INNER_Y, RIGHT_EYE_INNER_Z, RIGHT_EYE_X, RIGHT_EYE_Y, RIGHT_EYE_Z, RIGHT_EYE_OUTER_X, RIGHT_EYE_OUTER_Y, RIGHT_EYE_OUTER_Z, LEFT_EAR_X, LEFT_EAR_Y, LEFT_EAR_Z, RIGHT_EAR_X, RIGHT_EAR_Y, RIGHT_EAR_Z, MOUTH_LEFT_X, MOUTH_LEFT_Y, MOUTH_LEFT_Z, MOUTH_RIGHT_X, MOUTH_RIGHT_Y, MOUTH_RIGHT_Z, LEFT_SHOULDER_X, LEFT_SHOULDER_Y, LEFT_SHOULDER_Z, RIGHT_SHOULDER_X, RIGHT_SHOULDER_Y, RIGHT_SHOULDER_Z, LEFT_ELBOW_X, LEFT_ELBOW_Y, LEFT_ELBOW_Z, RIGHT_ELBOW_X, RIGHT_ELBOW_Y, RIGHT_ELBOW_Z, LEFT_WRIST_X, LEFT_WRIST_Y, LEFT_WRIST_Z, RIGHT_WRIST_X, RIGHT_WRIST_Y, RIGHT_WRIST_Z, LEFT_PINKY_X, LEFT_PINKY_Y, LEFT_PINKY_Z, RIGHT_PINKY_X, RIGHT_PINKY_Y, RIGHT_PINKY_Z, LEFT_INDEX_X, LEFT_INDEX_Y, LEFT_INDEX_Z, RIGHT_INDEX_X, RIGHT_INDEX_Y, RIGHT_INDEX_Z, LEFT_THUMB_X, LEFT_THUMB_Y, LEFT_THUMB_Z, RIGHT_THUMB_X, RIGHT_THUMB_Y, RIGHT_THUMB_Z, LEFT_HIP_X, LEFT_HIP_Y, LEFT_HIP_Z, RIGHT_HIP_X, RIGHT_HIP_Y, RIGHT_HIP_Z, LEFT_KNEE_X, LEFT_KNEE_Y, LEFT_KNEE_Z, RIGHT_KNEE_X, RIGHT_KNEE_Y, RIGHT_KNEE_Z, LEFT_ANKLE_X, LEFT_ANKLE_Y, LEFT_ANKLE_Z, RIGHT_ANKLE_X, RIGHT_ANKLE_Y, RIGHT_ANKLE_Z, LEFT_HEEL_X, LEFT_HEEL_Y, LEFT_HEEL_Z, RIGHT_HEEL_X, RIGHT_HEEL_Y, RIGHT_HEEL_Z, LEFT_FOOT_INDEX_X, LEFT_FOOT_INDEX_Y, LEFT_FOOT_INDEX_Z, RIGHT_FOOT_INDEX_X, RIGHT_FOOT_INDEX_Y, RIGHT_FOOT_INDEX_Z]
# Index: []
#
# [0 rows x 99 columns]

# %%
landmarks = results.pose_landmarks.landmark
print(len(landmarks))
print(landmarks[0])
# Out:
# 33
# x: 0.5649495124816895
# y: 0.3374246060848236
# z: -0.19197824597358704
# visibility: 0.9999687075614929

# %%
row = []
for i in range(len(landmarks)):
    broken = str(landmarks[i]).split("\n")
    for i in range(len(x)-2):
        row.append(float(x[i][3:]))

# %%
str(landmarks[0])
x = str(landmarks[0]).split("\n")

# %%
x
# Out:
# ['x: 0.5649495124816895',
#  'y: 0.3374246060848236',
#  'z: -0.19197824597358704',
#  'visibility: 0.9999687075614929',
#  '']

# %%
x[0]
# Out:
# 'x: 0.5649495124816895'

# %%
float(x[0][3:])
# Out:
# 0.5649495124816895

# %%
for i in range(len(x)-2):
    print(i)
    print(float(x[i][3:]))
# Out:
# 0
# 0.5649495124816895
# 1
# 0.3374246060848236
# 2
# -0.19197824597358704

# %%
row = []
row.append[]

# %%
send_data(results)
# Out:
# [x: 0.5649495124816895
# y: 0.3374246060848236
# z: -0.19197824597358704
# visibility: 0.9999687075614929
# , x: 0.5682440996170044
# y: 0.33344870805740356
# z: -0.17944273352622986
# visibility: 0.9999325275421143
# , x: 0.5704246759414673
# y: 0.3340761959552765
# z: -0.179438978433609
# visibility: 0.999930202960968
# , x: 0.572583019733429
# y: 0.33478519320487976
# z: -0.17944781482219696
# visibility: 0.9999403357505798
# , x: 0.5620869994163513
# y: 0.3331635594367981
# z: -0.17731519043445587
# visibility: 0.9999328255653381
# , x: 0.559860348701477
# y: 0.333736389875412
# z: -0.17732718586921692
# visibility: 0.9999271631240845
# , x: 0.5576006174087524
# y: 0.33442896604537964
# z: -0.17733630537986755
# visibility: 0.9999397397041321
# , x: 0.5772601366043091
# y: 0.3455028831958771
# z: -0.10832025855779648
# visibility: 0.9999144673347473
# , x: 0.5553354024887085
# y: 0.34707894921302795
# z: -0.09928794950246811
# visibility: 0.9998507499694824
# , x: 0.5697582960128784
# y: 0.3488749861717224
# z: -0.1659068763256073
# visibility: 0.9999570250511169
# , x: 0.5612676739692688
# y: 0.3492359519004822
# z: -0.16338558495044708
# visibility: 0.9999278783798218
# , x: 0.604190468788147
# y: 0.4228419363498688
# z: -0.06629707664251328
# visibility: 0.9999744892120361
# , x: 0.5373411774635315
# y: 0.4289286434650421
# z: -0.04758843034505844
# visibility: 0.9998518824577332
# , x: 0.6221953630447388
# y: 0.5050216913223267
# z: -0.02829733118414879
# visibility: 0.9921799302101135
# , x: 0.5228570103645325
# y: 0.5151301026344299
# z: -0.013911398127675056
# visibility: 0.9360170960426331
# , x: 0.6234968304634094
# y: 0.5919626355171204
# z: -0.08203175663948059
# visibility: 0.9823688268661499
# , x: 0.5311411023139954
# y: 0.586211085319519
# z: -0.0671130120754242
# visibility: 0.9319071769714355
# , x: 0.6253771781921387
# y: 0.6208088994026184
# z: -0.09942250698804855
# visibility: 0.9657487869262695
# , x: 0.531446099281311
# y: 0.6120729446411133
# z: -0.08533258736133575
# visibility: 0.8874099254608154
# , x: 0.621725857257843
# y: 0.6198407411575317
# z: -0.1204041838645935
# visibility: 0.9665287733078003
# , x: 0.5364983081817627
# y: 0.6079680323600769
# z: -0.1041928082704544
# visibility: 0.8895506262779236
# , x: 0.619390606880188
# y: 0.6119747757911682
# z: -0.09062948822975159
# visibility: 0.9560203552246094
# , x: 0.5379375219345093
# y: 0.5992603898048401
# z: -0.07551586627960205
# visibility: 0.8752259016036987
# , x: 0.5947161912918091
# y: 0.5949738025665283
# z: -0.011863009072840214
# visibility: 0.9998385310173035
# , x: 0.5570454597473145
# y: 0.6010479927062988
# z: 0.011729244142770767
# visibility: 0.9997865557670593
# , x: 0.5920571088790894
# y: 0.7365294694900513
# z: -0.0508265420794487
# visibility: 0.9505600333213806
# , x: 0.5642021894454956
# y: 0.7425730228424072
# z: -0.009400890208780766
# visibility: 0.9323429465293884
# , x: 0.5927950143814087
# y: 0.8633167743682861
# z: 0.08107359707355499
# visibility: 0.961537778377533
# , x: 0.5903664827346802
# y: 0.851503312587738
# z: 0.12752307951450348
# visibility: 0.9305335283279419
# , x: 0.5935863256454468
# y: 0.8783946633338928
# z: 0.08934184163808823
# visibility: 0.7751589417457581
# , x: 0.597415030002594
# y: 0.8636884689331055
# z: 0.13691440224647522
# visibility: 0.8130355477333069
# , x: 0.5967195630073547
# y: 0.9006203413009644
# z: 0.001789518864825368
# visibility: 0.9490919709205627
# , x: 0.5810182094573975
# y: 0.8980153203010559
# z: 0.058478742837905884
# visibility: 0.9245845079421997
# ]

# %% [markdown]
# # 1. Make Detections and save to excel

# %%
def send_data(results):
    landmarks = results.pose_landmarks.landmark
#     print(landmarks)
    row = []
    for i in range(len(landmarks)):
        broken = str(landmarks[i]).split("\n")
        for i in range(len(broken)-2):
            row.append(float(broken[i][3:]))
    df.loc[len(df)] = row

# %%
# col_names

# %%
# data = []
df = pd.DataFrame(columns=col_names)
cap = cv2.VideoCapture("hs.mp4")
## Setup mediapipe instance
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if ret == True:
        
            # Recolor image to RGB
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False  #helps save memory when passing to model

            # Make detection
            results = pose.process(image)
            send_data(results)
#             data.append(results.pose_landmarks.landmark)

            # Recolor back to BGR
            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

            # Render detections
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                    mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), #color of dots
                                    mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) #color of line
                                     )               

            cv2.imshow('Mediapipe Feed', image)

            if cv2.waitKey(10) & 0xFF == ord('q'):
                break
        else:
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
df
# Out:
#       NOSE_X    NOSE_Y    NOSE_Z  LEFT_EYE_INNER_X  LEFT_EYE_INNER_Y  \
# 0   0.518038  0.439390 -0.108634          0.518649          0.423682
# 1   0.516855  0.439312 -0.121272          0.517587          0.423691
# 2   0.516461  0.439310 -0.123982          0.517203          0.423737
# 3   0.514972  0.441880 -0.158104          0.515799          0.427201
# 4   0.514754  0.445222 -0.182075          0.515457          0.431146
# ..       ...       ...       ...               ...               ...
# 93  0.557594  0.338807 -0.170406          0.560832          0.334070
# 94  0.559278  0.339479 -0.182447          0.562484          0.334410
# 95  0.560787  0.339578 -0.180144          0.564108          0.334537
# 96  0.563056  0.339492 -0.184379          0.566272          0.334503
# 97  0.564950  0.337425 -0.191978          0.568244          0.333449
#
#     LEFT_EYE_INNER_Z  LEFT_EYE_X  LEFT_EYE_Y  LEFT_EYE_Z  LEFT_EYE_OUTER_X  \
# 0          -0.102308    0.521048    0.420817   -0.102359          0.523458
# 1          -0.115953    0.519817    0.420837   -0.116023          0.522220
# 2          -0.118695    0.519312    0.420921   -0.118767          0.521674
# 3          -0.154606    0.517839    0.424673   -0.154673          0.520029
# 4          -0.175171    0.517526    0.428566   -0.175220          0.519736
# ..               ...         ...         ...         ...               ...
# 93         -0.156051    0.562778    0.334628   -0.156049          0.564718
# 94         -0.168113    0.564486    0.334969   -0.168111          0.566543
# 95         -0.165993    0.566127    0.335081   -0.165991          0.568174
# 96         -0.170712    0.568391    0.335061   -0.170707          0.570532
# 97         -0.179443    0.570425    0.334076   -0.179439          0.572583
#
#     ...  LEFT_HEEL_Z  RIGHT_HEEL_X  RIGHT_HEEL_Y  RIGHT_HEEL_Z  \
# 0   ...    -0.114910      0.577745      0.879431     -0.035514
# 1   ...    -0.121217      0.568845      0.891441     -0.028643
# 2   ...    -0.131536      0.567361      0.889498     -0.029766
# 3   ...    -0.127877      0.566984      0.888391     -0.010873
# 4   ...    -0.126126      0.567522      0.887706     -0.015278
# ..  ...          ...           ...           ...           ...
# 93  ...     0.121957      0.583013      0.869155      0.143772
# 94  ...     0.087901      0.584121      0.860475      0.157212
# 95  ...     0.064238      0.594047      0.861180      0.150139
# 96  ...     0.039011      0.598608      0.863509      0.130678
# 97  ...     0.089342      0.597415      0.863688      0.136914
#
#     LEFT_FOOT_INDEX_X  LEFT_FOOT_INDEX_Y  LEFT_FOOT_INDEX_Z  \
# 0            0.544449           0.896257          -0.196082
# 1            0.545704           0.896926          -0.202314
# 2            0.546941           0.897530          -0.212604
# 3            0.549411           0.899460          -0.208913
# 4            0.550728           0.901759          -0.207899
# ..                ...                ...                ...
# 93           0.571295           0.904342           0.035646
# 94           0.571118           0.904122          -0.009975
# 95           0.568853           0.903884          -0.030459
# 96           0.578652           0.903797          -0.055853
# 97           0.596720           0.900620           0.001790
#
#     RIGHT_FOOT_INDEX_X  RIGHT_FOOT_INDEX_Y  RIGHT_FOOT_INDEX_Z
# 0             0.536952            0.886713           -0.105552
# 1             0.527916            0.887623           -0.097299
# 2             0.524995            0.887617           -0.098602
# 3             0.526680            0.889365           -0.077765
# 4             0.527758            0.891090           -0.081381
# ..                 ...                 ...                 ...
# 93            0.565885            0.895483            0.061636
# 94            0.566733            0.894893            0.084054
# 95            0.571739            0.897081            0.078844
# 96            0.574178            0.896742            0.056043
# 97            0.581018            0.898015            0.058479
#
# [98 rows x 99 columns]

# %%
df.to_csv("msd1.csv")
