# %%
import json
f = open('abc.json')
x = json.load(f)

# %%
x.keys()
# Out:
# dict_keys(['pages'])

# %%
ab = x["pages"]

# %%
y = ab[0]

# %%
y.keys()
# Out:
# dict_keys(['page_idx', 'dimensions', 'orientation', 'language', 'blocks'])

# %%
z = y["blocks"]

# %%
z
# Out:
# [{'geometry': [[0.0185546875, 0.01171875], [0.1123046875, 0.025390625]],
#   'lines': [{'geometry': [[0.0185546875, 0.01171875],
#      [0.1123046875, 0.025390625]],
#     'words': [{'value': 'PU19i',
#       'confidence': 0.3025885820388794,
#       'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]},
#      {'value': '(1-81',
#       'confidence': 0.5516065955162048,
#       'geometry': [[0.0712890625, 0.013671875],
#        [0.1123046875, 0.025390625]]}]}],
#   'artefacts': []},
#  {'geometry': [[0.3154296875, 0.0126953125], [0.375, 0.0244140625]],
#   'lines': [{'geometry': [[0.3154296875, 0.0126953125], [0.375, 0.0244140625]],
#     'words': [{'value': 'BROWN',
#       'confidence': 0.9985314607620239,
#       'geometry': [[0.3154296875, 0.0126953125],
#        [0.3603515625, 0.0244140625]]},
#      {'value': 'a',
#       'confidence': 0.9988600611686707,
#       'geometry': [[0.3623046875, 0.0146484375], [0.375, 0.0244140625]]}]}],
#   'artefacts': []},
# ...

# %%
len(z)
# Out:
# 37

# %%
z
# Out:
# [{'geometry': [[0.0185546875, 0.01171875], [0.1123046875, 0.025390625]],
#   'lines': [{'geometry': [[0.0185546875, 0.01171875],
#      [0.1123046875, 0.025390625]],
#     'words': [{'value': 'PU19i',
#       'confidence': 0.3025885820388794,
#       'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]},
#      {'value': '(1-81',
#       'confidence': 0.5516065955162048,
#       'geometry': [[0.0712890625, 0.013671875],
#        [0.1123046875, 0.025390625]]}]}],
#   'artefacts': []},
#  {'geometry': [[0.3154296875, 0.0126953125], [0.375, 0.0244140625]],
#   'lines': [{'geometry': [[0.3154296875, 0.0126953125], [0.375, 0.0244140625]],
#     'words': [{'value': 'BROWN',
#       'confidence': 0.9985314607620239,
#       'geometry': [[0.3154296875, 0.0126953125],
#        [0.3603515625, 0.0244140625]]},
#      {'value': 'a',
#       'confidence': 0.9988600611686707,
#       'geometry': [[0.3623046875, 0.0146484375], [0.375, 0.0244140625]]}]}],
#   'artefacts': []},
# ...

# %%
# for we in range(len(z)):
for we in range(1):
    last = z[we]
    s = last["lines"]

# %%
last = z[0]

# %%
last
# Out:
# {'geometry': [[0.0185546875, 0.01171875], [0.1123046875, 0.025390625]],
#  'lines': [{'geometry': [[0.0185546875, 0.01171875],
#     [0.1123046875, 0.025390625]],
#    'words': [{'value': 'PU19i',
#      'confidence': 0.3025885820388794,
#      'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]},
#     {'value': '(1-81',
#      'confidence': 0.5516065955162048,
#      'geometry': [[0.0712890625, 0.013671875],
#       [0.1123046875, 0.025390625]]}]}],
#  'artefacts': []}

# %%
last.keys()
# Out:
# dict_keys(['geometry', 'lines', 'artefacts'])

# %%
s = last["lines"]

# %%
s
# Out:
# [{'geometry': [[0.0185546875, 0.01171875], [0.1123046875, 0.025390625]],
#   'words': [{'value': 'PU19i',
#     'confidence': 0.3025885820388794,
#     'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]},
#    {'value': '(1-81',
#     'confidence': 0.5516065955162048,
#     'geometry': [[0.0712890625, 0.013671875], [0.1123046875, 0.025390625]]}]}]

# %%
s[0]
# Out:
# {'geometry': [[0.0185546875, 0.01171875], [0.1123046875, 0.025390625]],
#  'words': [{'value': 'PU19i',
#    'confidence': 0.3025885820388794,
#    'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]},
#   {'value': '(1-81',
#    'confidence': 0.5516065955162048,
#    'geometry': [[0.0712890625, 0.013671875], [0.1123046875, 0.025390625]]}]}

# %%
d2 = s[0]["words"]

# %%
d2
# Out:
# [{'value': 'PU19i',
#   'confidence': 0.3025885820388794,
#   'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]},
#  {'value': '(1-81',
#   'confidence': 0.5516065955162048,
#   'geometry': [[0.0712890625, 0.013671875], [0.1123046875, 0.025390625]]}]

# %%
for x in d2:
    print(x)
#     print(x["value"])
# Out:
# {'value': 'PU19i', 'confidence': 0.3025885820388794, 'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]}
# {'value': '(1-81', 'confidence': 0.5516065955162048, 'geometry': [[0.0712890625, 0.013671875], [0.1123046875, 0.025390625]]}

# %%
for x in range (len(s)):
    wl = s[x]["words"]
    for za in (wl):
        print(za["value"])
# Out:
# PU19i
# (1-81

# %%
wl2 = []
for we in range(len(z)):
    last = z[we]
    s = last["lines"]
    for x in range (len(s)):
        wl = s[x]["words"]
        for za in (wl):
            print(za)
            wl2.append(za)
#             print(za["value"])
# Out:
# {'value': 'PU19i', 'confidence': 0.3025885820388794, 'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]}
# {'value': '(1-81', 'confidence': 0.5516065955162048, 'geometry': [[0.0712890625, 0.013671875], [0.1123046875, 0.025390625]]}
# {'value': 'BROWN', 'confidence': 0.9985314607620239, 'geometry': [[0.3154296875, 0.0126953125], [0.3603515625, 0.0244140625]]}
# {'value': 'a', 'confidence': 0.9988600611686707, 'geometry': [[0.3623046875, 0.0146484375], [0.375, 0.0244140625]]}
# {'value': 'MATERI', 'confidence': 0.7399580478668213, 'geometry': [[0.3076171875, 0.02734375], [0.3583984375, 0.0380859375]]}
# {'value': 'AL', 'confidence': 0.9349808096885681, 'geometry': [[0.3544921875, 0.0283203125], [0.373046875, 0.037109375]]}
# {'value': 'SPECIFICATIONOR', 'confidence': 0.5998489260673523, 'geometry': [[0.4013671875, 0.02734375], [0.5234375, 0.0380859375]]}
# ...

# %%
wl2
# Out:
# [{'value': 'PU19i',
#   'confidence': 0.3025885820388794,
#   'geometry': [[0.0185546875, 0.01171875], [0.0625, 0.0224609375]]},
#  {'value': '(1-81',
#   'confidence': 0.5516065955162048,
#   'geometry': [[0.0712890625, 0.013671875], [0.1123046875, 0.025390625]]},
#  {'value': 'BROWN',
#   'confidence': 0.9985314607620239,
#   'geometry': [[0.3154296875, 0.0126953125], [0.3603515625, 0.0244140625]]},
#  {'value': 'a',
#   'confidence': 0.9988600611686707,
#   'geometry': [[0.3623046875, 0.0146484375], [0.375, 0.0244140625]]},
#  {'value': 'MATERI',
#   'confidence': 0.7399580478668213,
#   'geometry': [[0.3076171875, 0.02734375], [0.3583984375, 0.0380859375]]},
#  {'value': 'AL',
#   'confidence': 0.9349808096885681,
#   'geometry': [[0.3544921875, 0.0283203125], [0.373046875, 0.037109375]]},
#  {'value': 'SPECIFICATIONOR',
#   'confidence': 0.5998489260673523,
#   'geometry': [[0.4013671875, 0.02734375], [0.5234375, 0.0380859375]]},
#  {'value': 'DESIGN',
# ...

# %%
len(wl2)
# Out:
# 157

# %%
for i in range(len(wl2)):
    print(wle)

# %%
x3 = wl2.copy()

# %%
li = []
for x in x3:
    li.append(x["value"])
    print(x['value'])
# Out:
# PU19i
# (1-81
# BROWN
# a
# MATERI
# AL
# SPECIFICATIONOR
# DESIGN
# CHANGE
# AUTHORI:
# ZATI
# ON
# NEW
# ITEM
# DESCRIPTION
# BRARDIS)
# DESI
# GN
# NO.
# TYPE
# CHANGE:
# VICEROY
# Rich
# Lights
# 100's
# 20's
# Label
# Rich
# Lights
# 81-257
# OTEMPORARY
# 272972
# MILITARY
# CENO
# 50-034A
# UPC
# NO.
# USE:
# MATERIAL
# NO.
# PHETOMER
# SPEC.
# (GRAVUREI
# Isamaterisordimensionschangalsdinvolved
# DYES
# ttyes,supplydetail
# BRANCH
# SCHEDULE:
# DATE
# OR
# DELIVERY
# DATE
# REPLACEMENT
# OESCRIPTION
# NO.
# BRANCH
# DEPLETION
# DATE
# LOUISVILLE
# 10/30/81
# 10/16/81
# PETERSBURG
# MACON
# WINSTON
# SALEM
# VICEROY
# Rich
# Lights
# 100's
# 20's
# Label
# 80-15
# 272972
# PETERSBURG
# 50-034
# NO.
# WINSTON-SALEM
# UPC
# NO.
# LOUISVILLE
# 10/30/81
# MACON
# Material
# #50-034A
# has
# been
# assigmed
# to
# the
# VICEROY
# Rich
# Lights
# 100's
# 20's
# Label
# with
# new
# bottom
# pamel.
# Bottom
# now
# incorporates
# shield.
# On
# both
# side
# amd
# bottom
# pamels,
# ...

# %%
len(li)
# Out:
# 157
