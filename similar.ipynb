# %%
from get_data import extract
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("msd_main.csv")

# %%
df = df.iloc[: , 1:]

# %%
df
# Out:
#     LEFT_SHOULDER_X  LEFT_SHOULDER_Y  LEFT_SHOULDER_Z  RIGHT_SHOULDER_X  \
# 0          0.571178         0.425766        -0.104015          0.554026
# 1          0.570931         0.428420        -0.100361          0.553907
# 2          0.570780         0.429787        -0.099161          0.553824
# 3          0.570050         0.431232        -0.095383          0.553532
# 4          0.569362         0.433093        -0.088930          0.553266
# ..              ...              ...              ...               ...
# 82         0.557495         0.420161         0.006033          0.498803
# 83         0.559342         0.417939         0.003437          0.501437
# 84         0.562026         0.416667         0.003349          0.503398
# 85         0.563768         0.414370         0.005404          0.506103
# 86         0.564500         0.413524         0.006769          0.507015
#
#     RIGHT_SHOULDER_Y  RIGHT_SHOULDER_Z  LEFT_ELBOW_X  LEFT_ELBOW_Y  \
# ...

# %% [markdown]
# # Extract co-ordinates of any new video

# %%
js = extract("ps6.mp4")
# Out:
# yes
# done

# %%
js.shape[0]
# Out:
# 90

# %% [markdown]
# # comparing graphs of individual columns/pointers

# %%
for x in range(df.shape[1]):
    plt.figure(figsize=(7,4))
    df.iloc[:,x].plot(),js.iloc[:,x].plot()
    plt.title(df.columns[x])
    plt.show()

# %% [markdown]
# # co-relation of both dataframes

# %%
print(df.corrwith(other=js))
# Out:
# LEFT_SHOULDER_X       0.245102
# LEFT_SHOULDER_Y       0.735903
# LEFT_SHOULDER_Z       0.549777
# RIGHT_SHOULDER_X      0.891925
# RIGHT_SHOULDER_Y      0.553365
# RIGHT_SHOULDER_Z      0.262589
# LEFT_ELBOW_X          0.436650
# LEFT_ELBOW_Y          0.765048
# LEFT_ELBOW_Z         -0.143924
# RIGHT_ELBOW_X         0.873433
# RIGHT_ELBOW_Y         0.444772
# RIGHT_ELBOW_Z         0.269414
# LEFT_WRIST_X          0.606879
# LEFT_WRIST_Y          0.550258
# LEFT_WRIST_Z          0.176508
# RIGHT_WRIST_X         0.669433
# RIGHT_WRIST_Y         0.407654
# RIGHT_WRIST_Z         0.501358
# LEFT_HIP_X            0.947734
# LEFT_HIP_Y            0.381624
# LEFT_HIP_Z            0.673542
# RIGHT_HIP_X           0.961200
# RIGHT_HIP_Y           0.372515
# RIGHT_HIP_Z           0.675583
# LEFT_KNEE_X           0.412239
# LEFT_KNEE_Y           0.105896
# LEFT_KNEE_Z           0.791421
# RIGHT_KNEE_X          0.930136
# RIGHT_KNEE_Y          0.060094
# RIGHT_KNEE_Z         -0.130294
# ...

# %%
d = {}
for x in range(df.shape[1]):
#     print(df.iloc[:,x].corr(js.iloc[:,x]), "of ", df.columns[x])
    d[df.columns[x]] = df.iloc[:,x].corr(js.iloc[:,x])
sum = 0
for x in d.values():
    sum = x*100 + sum
print("you match dhoni by ",sum/48," %")
# Out:
# you match dhoni by  44.46722231802351  %

# %%
df
# Out:
#     LEFT_SHOULDER_X  LEFT_SHOULDER_Y  LEFT_SHOULDER_Z  RIGHT_SHOULDER_X  \
# 0          0.571178         0.425766        -0.104015          0.554026
# 1          0.570931         0.428420        -0.100361          0.553907
# 2          0.570780         0.429787        -0.099161          0.553824
# 3          0.570050         0.431232        -0.095383          0.553532
# 4          0.569362         0.433093        -0.088930          0.553266
# ..              ...              ...              ...               ...
# 82         0.557495         0.420161         0.006033          0.498803
# 83         0.559342         0.417939         0.003437          0.501437
# 84         0.562026         0.416667         0.003349          0.503398
# 85         0.563768         0.414370         0.005404          0.506103
# 86         0.564500         0.413524         0.006769          0.507015
#
#     RIGHT_SHOULDER_Y  RIGHT_SHOULDER_Z  LEFT_ELBOW_X  LEFT_ELBOW_Y  \
# ...

# %% [markdown]
# <img src="https://i.imgur.com/3j8BPdc.png" style="height:300px" >

# %%
def calculate_angle(a,b,c):
    a = np.array(a) # First
    b = np.array(b) # Mid  (main jis point ka angle nikalta)
    c = np.array(c) # End
    
    radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
    angle = np.abs(radians*180.0/np.pi)
    
    if angle >180.0:
        angle = 360-angle
        
    return angle
